# %%
from load_dictionary import load

df = load('3of6game.txt')
print(df[0:10])
# Out:
# ['a', 'aah', 'aardvark', 'aardvarks', 'abaci$', 'aback', 'abacus', 'abacuses', 'abalone', 'abalones']

# %% [markdown]
# #### Finds plindromes in the dicitionary file.

# %%
from load_dictionary import load
import pandas as pd
word_list = load_dictionary.load('3of6game.txt')
plingram_list = [] 

for word in word_list:
    if len(word) > 1 and word == word[::-1]:
        plingram_list.append(word)

print("{} palindromes found.\n".format(len(plingram_list)))
df = pd.DataFrame(plingram_list)
print (df.head(10))
# Out:
# 59 palindromes found.
#
#          0
# 0      aha
# 1      bib
# 2      bob
# 3     boob
# 4      bub
# 5    civic
# 6      dad
# 7     deed
# 8  deified
# 9      did

# %%
from palingrams import find_palingrams
from load_dictionary import load

dict_words = load('3of6game.txt')
palingrams = find_palingrams(dict_words)
sorted_palingrams = sorted(palingrams)
print(f"\nNumber of palingrams:{len(palingrams)}\n")
for first,second in sorted_palingrams:
    print(f"{first} {second}")
# Out:
# Number of palingrams:1948
#
# a fa
# a ha
# a la
# a ma
# a pa
# a ta
# abuts tuba
# acidic a
# across orca
# ad a
# add a
# ado coda
# ado soda
# aft fa
# age mega
# ago toga
# ago yoga
# agog a
# ah a
# ah aha
# aha ha
# aide media
# air aria
# ale la
# alibi la
# all a
# all la
# aloo la
# am a
# amen enema
# ammo comma
# ammo momma
# amoral aroma
# amp ma
# an a
# anon a
# ape pa
# app a
# app pa
# apse spa
# apses pa
# apt pa
# are sera
# area era
# ares era
# ark okra
# as a
# asks a
# asps a
# ass a
# assess a
# at a
# ate beta
# ate feta
# ate ta
# avow ova
# aw a
# ax a
# ay a
# babe kebab
# bacilli cab
# back cab
# bade dab
# bags gab
# bald lab
# bale lab
# balk lab
# ball lab
# balm lab
# balsa slab
# banana nab
# band nab
# banded nab
# bane nab
# bang nab
# bank nab
# bans nab
# bar crab
# bar drab
# bar grab
# bards drab
# barge grab
# bat stab
# bath tab
# bats tab
# be deb
# be web
# bedded deb
# beds deb
# bi bib
# bi fib
# bi jib
# bi lib
# bi nib
# bi rib
# ...

# %%
dict_words = load('3of6game.txt')
print(len(dict_words))
# Out:
# 64662
